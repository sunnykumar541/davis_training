# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnykumar541/davis_training/blob/main/self%20learning/addition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = 25
num2 = 73

sum_result = num1 + num2

print(f"The sum of {num1} and {num2} is: {sum_result}")
# Out:
# The sum of 25 and 73 is: 98
